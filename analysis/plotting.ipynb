# %%
import scipy, pandas, numpy
import matplotlib.pyplot as plt  

df = pandas.read_csv('sme_finance_monitor_final.csv')
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'outcome', 'q35b_1', 'q35b_2', 'q35b_3', 'q35b_4',
#        'q35b_5', 'q35b_6', 'q35b_7', 'q35b_8',
#        ...
#        'q119_5.0', 'q119_6.0', 'q119_7.0', 'q119_8.0', 'q119_10.0',
#        'q119_11.0', 'q119_12.0', 'q119_13.0', 'q119_14.0', 'q119_15.0'],
#       dtype='object', length=644)

# %%
# count the number that q126 is 1 and outcome is 1 in pandas
print(df[df['q126_1'] == 1]['outcome'].value_counts())
print(df[df['q126_2'] == 1]['outcome'].value_counts())
print(df[df['q126_3'] == 1]['outcome'].value_counts())
# Out:
# 1    1604
# 0     221
# Name: outcome, dtype: int64
# 1    414
# 0     49
# Name: outcome, dtype: int64
# 1    30
# 0     5
# Name: outcome, dtype: int64

# %%
# create data: an array of values
group1=[1604,221]
group2=[414,49]
group3=[30,5]
# Create three pieplots with group1 group2 group3
plt.pie(group1, labels=['Succeed', 'Declined'], autopct='%1.1f%%')
plt.show()

# %%
plt.pie(group2, labels=['Succeed', 'Declined'], autopct='%1.1f%%')
plt.show()

# %%
plt.pie(group3, labels=['Succeed', 'Declined'], autopct='%1.1f%%')
plt.show()

# %%
#gender of leaders 
# group1=[2048,285]
group1=[2018,270]
group2=[1604,221]
group3=[414,49]
group4=[30,5]
pic1 = plt.figure(figsize=(17,60),dpi=120)
fig1 = pic1.add_subplot(1,3,1)
plt.pie(group1, labels=['Succeed', 'Declined'], autopct='%1.1f%%', shadow=True ,explode=[0.02,0.02])
plt.title('Overall final outcome',fontsize=12)
fig2 = pic1.add_subplot(1,3,2)
plt.pie(group2, labels=['Succeed', 'Declined'], autopct='%1.1f%%', shadow=True ,explode=[0.02,0.02])
plt.title('Final outcome in terms of MEN',fontsize=12)
fig3 = pic1.add_subplot(1,3,3)
plt.pie(group3, labels=['Succeed', 'Declined'], autopct='%1.1f%%', shadow=True ,explode=[0.02,0.02])
plt.title('Final outcome in terms of WOMEN',fontsize=12)
plt.savefig('./fig/gender.jpg',dpi=200, bbox_inches='tight')
plt.show()
#save the figure with name gender

# %%
# count the number that q126 is 1 and outcome is 1 in pandas
df1 = pandas.read_csv('sme_finance_monitor_preprocess.csv')
df1 = pandas.get_dummies(df1, columns=['q126'])
print(df1[df1['q126_1'] == 1]['q24b'].value_counts())
print(df1[df1['q126_2'] == 1]['q24b'].value_counts())
print(df1[df1['q126_3'] == 1]['q24b'].value_counts())
# Out:
# 8     467
# 10    330
# 7     248
# 9     209
# 5     207
# 6     128
# 1      93
# 4      63
# 3      50
# 2      35
# Name: q24b, dtype: int64
# 8     108
# 10     84
# 7      75
# 9      60
# 5      54
# 6      32
# 1      20
# 4      14
# 2       9
# 3       7
# Name: q24b, dtype: int64
# 8     8
# 10    7
# 7     5
# 5     5
# 6     4
# 1     3
# 3     2
# 9     1
# Name: q24b, dtype: int64

# %%
group1=[291, 744, 1257]
# group1=[113,44,57,77,261,160,323,575,269,413]
group2=[241, 583, 1006]
# group2=[93,35,50,63,207,128,248,467,209,330]
group3=[50, 161, 251]
# group3=[20,9,7,14,54,32,75,108,60,83]
pic1 = plt.figure(figsize=(17,60),dpi=120)
fig1 = pic1.add_subplot(1,3,1)
plt.pie(group1, labels=['Low', 'Medium', 'High'], autopct='%1.1f%%', shadow=True, explode=[0.02,0.02,0.02] )
plt.title('Overall',fontsize=12)
fig2 = pic1.add_subplot(1,3,2)
plt.pie(group2, labels=['Low', 'Medium', 'High'], autopct='%1.1f%%', shadow=True, explode=[0.02,0.02,0.02])
plt.title('MEN',fontsize=12)
fig3 = pic1.add_subplot(1,3,3)
plt.pie(group3, labels=['Low', 'Medium', 'High'], autopct='%1.1f%%', shadow=True, explode=[0.02,0.02,0.02] )
plt.title('WOMEN',fontsize=12)
plt.savefig('./fig/gender_trust.jpg',dpi=200, bbox_inches='tight')
plt.show()

# %%
#ethnic of leaders 
print(df.filter(like='q144').columns)
# Any white background
print(df[(df['q144_1'] == 1)|(df['q144_2'] == 1)|(df['q144_3'] == 1)]['outcome'].value_counts())
# Any mixed background
print(df[(df['q144_4'] == 1)|(df['q144_5'] == 1)|(df['q144_6'] == 1)|(df['q144_7'] == 1)]['outcome'].value_counts())
# Any Asian background
print(df[(df['q144_8'] == 1)|(df['q144_9'] == 1)|(df['q144_10'] == 1)|(df['q144_11'] == 1)]['outcome'].value_counts())
# Any Black background
print(df[(df['q144_12'] == 1)|(df['q144_13'] == 1)|(df['q144_14'] == 1)]['outcome'].value_counts())
# Chinese background
print(df[(df['q144_15'] == 1)]['outcome'].value_counts())
# Other background
print(df[(df['q144_16'] == 1)]['outcome'].value_counts())
# Not answered
print(df[(df['q144_17'] == 1)|(df['q144_18'] == 1)]['outcome'].value_counts())
# Out:
# Index(['q144_1', 'q144_2', 'q144_3', 'q144_4', 'q144_5', 'q144_6', 'q144_7',
#        'q144_8', 'q144_9', 'q144_10', 'q144_11', 'q144_12', 'q144_13',
#        'q144_14', 'q144_15', 'q144_16', 'q144_17', 'q144_18'],
#       dtype='object')
# 1    1607
# 0     203
# Name: outcome, dtype: int64
# 1    18
# 0     5
# Name: outcome, dtype: int64
# 1    51
# 0    12
# Name: outcome, dtype: int64
# 1    17
# 0     6
# Name: outcome, dtype: int64
# 1    2
# 0    1
# Name: outcome, dtype: int64
# 0    1
# Name: outcome, dtype: int64
# 1    353
# 0     47
# Name: outcome, dtype: int64

# %%
#ethnic of leaders 
group1=[2048,285] #Overall
group2=[1607,203] #white background
group3=[53,13] #asian background
group4=[17,6] #black background
group5=[18,5] #mixed background
group6=[353,48] #DK

pic1 = plt.figure(figsize=(13,50),dpi=100)
fig1 = pic1.add_subplot(2,3,1)
plt.pie(group1, labels=['Succeed', 'Declined'], autopct='%1.1f%%', shadow=True ,explode=[0.02,0.02])
plt.title('Overall',fontsize=12)
fig2 = pic1.add_subplot(2,3,2)
plt.pie(group2, labels=['Succeed', 'Declined'], autopct='%1.1f%%', shadow=True ,explode=[0.02,0.02])
plt.title('White background',fontsize=12)
fig3 = pic1.add_subplot(2,3,3)
plt.pie(group3, labels=['Succeed', 'Declined'], autopct='%1.1f%%', shadow=True ,explode=[0.02,0.02])
plt.title('Asian background',fontsize=12)
fig3 = pic1.add_subplot(2,3,4)
plt.pie(group4, labels=['Succeed', 'Declined'], autopct='%1.1f%%', shadow=True ,explode=[0.02,0.02])
plt.title('Black background',fontsize=12)
fig3 = pic1.add_subplot(2,3,5)
plt.pie(group3, labels=['Succeed', 'Declined'], autopct='%1.1f%%', shadow=True ,explode=[0.02,0.02])
plt.title('Mixed background',fontsize=12)
fig3 = pic1.add_subplot(2,3,6)
plt.pie(group3, labels=['Succeed', 'Declined'], autopct='%1.1f%%', shadow=True ,explode=[0.02,0.02])
plt.title('Don\'t know',fontsize=12)
plt.subplots_adjust(wspace=0, hspace=-.87)
plt.savefig('./fig/ethnic.jpg',dpi=150, bbox_inches='tight')
plt.show()

# %%
# count the number that q126 is 1 and outcome is 1 in pandas
df1 = pandas.read_csv('sme_finance_monitor_preprocess.csv')

df1 = pandas.get_dummies(df1, columns=['q144'])

df1['q24b_new']='low'
df1.loc[(df1['q24b']==1)|(df1['q24b']==2)|(df1['q24b']==3)|(df1['q24b']==4),'q24b_new'] = 'low'
df1.loc[(df1['q24b']==5)|(df1['q24b']==6)|(df1['q24b']==7),'q24b_new'] = 'medium'
df1.loc[(df1['q24b']==8)|(df1['q24b']==9)|(df1['q24b']==10),'q24b_new'] = 'high'
# Any white background
print(df1[(df1['q144_1'] == 1)|(df1['q144_2'] == 1)|(df1['q144_3'] == 1)]['q24b_new'].value_counts())
# Any mixed background
print(df1[(df1['q144_4'] == 1)|(df1['q144_5'] == 1)|(df1['q144_6'] == 1)|(df1['q144_7'] == 1)]['q24b_new'].value_counts())
# Any Asian background
print(df1[(df1['q144_8'] == 1)|(df1['q144_9'] == 1)|(df1['q144_10'] == 1)|(df1['q144_11'] == 1)|(df1['q144_15'] == 1)]['q24b_new'].value_counts())
# Any Black background
print(df1[(df1['q144_12'] == 1)|(df1['q144_13'] == 1)|(df1['q144_14'] == 1)]['q24b_new'].value_counts())
# Not answered
print(df1[(df1['q144_16'] == 1)|(df1['q144_17'] == 1)|(df1['q144_18'] == 1)]['q24b_new'].value_counts())
# Out:
# high      984
# medium    597
# low       231
# Name: q24b_new, dtype: int64
# high      14
# medium     7
# low        2
# Name: q24b_new, dtype: int64
# high      32
# medium    27
# low        8
# Name: q24b_new, dtype: int64
# medium    13
# high       8
# low        2
# Name: q24b_new, dtype: int64
# high      236
# medium    114
# low        53
# Name: q24b_new, dtype: int64

# %%
#ethnic of leaders 
group1=[331,753,1244] #Overall
group2=[231,597,984] #white background
group3=[32,27,8] #asian background
group4=[13,8,2] #black background
group5=[2,7,14] #mixed background
group6=[53,114,236] #DK

pic1 = plt.figure(figsize=(13,50),dpi=100)
fig1 = pic1.add_subplot(2,3,1)
plt.pie(group1, labels=['Low', 'Medium', 'High'], autopct='%1.1f%%', shadow=True, explode=[0.02,0.02,0.02] )
plt.title('Overall',fontsize=12)
fig2 = pic1.add_subplot(2,3,2)
plt.pie(group2, labels=['Low', 'Medium', 'High'], autopct='%1.1f%%', shadow=True, explode=[0.02,0.02,0.02] )
plt.title('White background',fontsize=12)
fig3 = pic1.add_subplot(2,3,3)
plt.pie(group3, labels=['Low', 'Medium', 'High'], autopct='%1.1f%%', shadow=True, explode=[0.02,0.02,0.02] )
plt.title('Asian background',fontsize=12)
fig3 = pic1.add_subplot(2,3,4)
plt.pie(group4, labels=['Low', 'Medium', 'High'], autopct='%1.1f%%', shadow=True, explode=[0.02,0.02,0.02] )
plt.title('Black background',fontsize=12)
fig3 = pic1.add_subplot(2,3,5)
plt.pie(group5, labels=['Low', 'Medium', 'High'], autopct='%1.1f%%', shadow=True, explode=[0.02,0.02,0.02] )
plt.title('Mixed background',fontsize=12)
fig3 = pic1.add_subplot(2,3,6)
plt.pie(group6, labels=['Low', 'Medium', 'High'], autopct='%1.1f%%', shadow=True, explode=[0.02,0.02,0.02] )
plt.title('Don\'t know',fontsize=12)
plt.subplots_adjust(wspace=0, hspace=-.87)
plt.savefig('./fig/ethnic_trust.jpg',dpi=150, bbox_inches='tight')
plt.show()
